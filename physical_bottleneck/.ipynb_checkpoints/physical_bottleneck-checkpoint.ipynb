# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import h5py
import torch
from tqdm.auto import tqdm

import warnings
warnings.filterwarnings('ignore')

import matplotlib
import matplotlib.pyplot as plt
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
np.set_printoptions(precision=2, suppress=False)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import dolfin_adjoint as d_ad
from data_processing import scalar_img_to_mesh
def plot_mesh(ax, f, mesh, lw=False, scale=1, vmin=0, vmax=1, **kwargs):
    x, y = mesh.coordinates()[:, 0], mesh.coordinates()[:, 1]
    tri = mesh.cells()
    if lw:
        kwargs['edgecolors'] = 'black'
        kwargs['linewidth'] = 0.05
    if not isinstance(f, np.ndarray):
        ax.tripcolor(x, y, f.compute_vertex_values() * scale, triangles=tri, vmin=vmin, vmax=vmax, **kwargs)
    else:
        ax.tripcolor(x, y, f * scale, triangles=tri, vmin=vmin, vmax=vmax, **kwargs)
    ax.set(xticks=[], yticks=[])

from data_processing import StationaryDataset
county = 'cook_IL'
dataset = StationaryDataset(county)

fig, ax = plt.subplots(3, 2, dpi=150, sharey=True, sharex=True)

sample = dataset.get_time(1980)
ax[0,0].pcolormesh(sample['x'], sample['y'], sample['wb0'][0], cmap='Blues', vmax=1, vmin=0)
ax[0,1].pcolormesh(sample['x'], sample['y'], sample['wb0'][1], cmap='Reds', vmax=1, vmin=0)

sample = dataset[30]

#Generate fields on mesh
V = sample['FctSpace']
N = V.dim()
Dww = d_ad.Function(V)
Dwb = d_ad.Function(V)
Dbw = d_ad.Function(V)
Dbb = d_ad.Function(V)
w0 = d_ad.Function(V)
b0 = d_ad.Function(V)

Dww.vector()[:] = sample['control_arr'][:N]
Dwb.vector()[:] = sample['control_arr'][N:2*N]
Dbw.vector()[:] = sample['control_arr'][2*N:3*N]
Dbb.vector()[:] = sample['control_arr'][3*N:4*N]

GammaW = d_ad.Constant(sample['control_arr'][4*N], name='gammaW')
GammaB = d_ad.Constant(sample['control_arr'][4*N+1], name='gammaB')
dt = d_ad.Constant(sample['dt'], name='dt')
#w0 = scalar_img_to_mesh(sample['wb0'][0], sample['x'], sample['y'], sample['FctSpace'])
#b0 = scalar_img_to_mesh(sample['wb0'][1], sample['x'], sample['y'], sample['FctSpace'])
w0.vector()[:] = sample['control_arr'][4*N+3:5*N+3]
b0.vector()[:] = sample['control_arr'][5*N+3:6*N+3]

wb, _, _ = sample['pde_forward'](Dww, Dwb, Dbw, Dbb, GammaW, GammaB, 10, w0, b0, dataset.mesh)
w1, b1 = wb.split(True)

plot_mesh(ax[1,0], w0, dataset.mesh, cmap='Blues')
plot_mesh(ax[1,1], b0, dataset.mesh, cmap='Reds')

plot_mesh(ax[2,0], w1, dataset.mesh, cmap='Blues')
plot_mesh(ax[2,1], b1, dataset.mesh, cmap='Reds')

ax[0,0].set_title('White occupation', fontsize=8)
ax[0,1].set_title('Black occupation', fontsize=8)
ax[0,0].set_ylabel('1980')
ax[1,0].set_ylabel('2020')
ax[2,0].set_ylabel('2030 (predicted)')
for a in ax.flatten():
    a.set_aspect('equal')
    a.set(xticks=[], yticks=[])
plt.tight_layout()
# Out:
# [autoreload of data_processing failed: Traceback (most recent call last):
#   File "/project/vitelli/ml_venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/project/vitelli/ml_venv/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 394, in superreload
#     module = reload(module)
#   File "/project/vitelli/ml_venv/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/project/vitelli/ml_venv/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
#   File "<frozen importlib._bootstrap>", line 219, in _call_with_frames_removed
#   File "/home/jcolen/sociohydro/physical_bottleneck/data_processing.py", line 210
#     def get_dolfin(self, sample):
#       ^
# IndentationError: expected an indented block
# ]
# [Coefficient(FunctionSpace(Mesh(VectorElement(FiniteElement('Lagrange', triangle, 1), dim=2), 21398786), FiniteElement('Lagrange', triangle, 1)), 21398821), Coefficient(FunctionSpace(Mesh(VectorElement(FiniteElement('Lagrange', triangle, 1), dim=2), 21398786), FiniteElement('Lagrange', triangle, 1)), 21398826), Coefficient(FunctionSpace(Mesh(VectorElement(FiniteElement('Lagrange', triangle, 1), dim=2), 21398786), FiniteElement('Lagrange', triangle, 1)), 21398831), Coefficient(FunctionSpace(Mesh(VectorElement(FiniteElement('Lagrange', triangle, 1), dim=2), 21398786), FiniteElement('Lagrange', triangle, 1)), 21398836), Coefficient(FunctionSpace(None, FiniteElement('Real', None, 0)), 21398817), Coefficient(FunctionSpace(None, FiniteElement('Real', None, 0)), 21398818), None, Coefficient(FunctionSpace(Mesh(VectorElement(FiniteElement('Lagrange', triangle, 1), dim=2), 21398786), FiniteElement('Lagrange', triangle, 1)), 21398875), Coefficient(FunctionSpace(Mesh(VectorElement(FiniteElement('Lagrange', triangle, 1), dim=2), 21398786), FiniteElement('Lagrange', triangle, 1)), 21398880)]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-7dc0076e8b8f> in <module>
#      19 fig, ax = plt.subplots(3, 2, dpi=150, sharey=True, sharex=True)
#      20
# ---> 21 sample = dataset.get_time(1980)
#      22 ax[0,0].pcolormesh(sample['x'], sample['y'], sample['wb0'][0], cmap='Blues', vmax=1, vmin=0)
#      23 ax[0,1].pcolormesh(sample['x'], sample['y'], sample['wb0'][1], cmap='Reds', vmax=1, vmin=0)
#
# ~/sociohydro/physical_bottleneck/data_processing.py in get_time(self, t)
#     302         }
#     303         pde = self.get_dolfin(sample)
# --> 304         return {**sample, **pde}
#     305
#     306     def __getitem__(self, idx):
#
# ~/sociohydro/physical_bottleneck/data_processing.py in get_dolfin(self, sample)
#     278         control_arr = [p.data() for p in Jhat_np.controls]
#     279         control_arr = Jhat_np.obj_to_array(control_arr)
# --> 280
#     281         return {
#     282             'Jhat': Jhat_np,
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/reduced_functional_numpy.py in obj_to_array(self, obj)
#     103
#     104     def obj_to_array(self, obj):
# --> 105         return self.get_global(obj)
#     106
#     107     def get_controls(self):
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/reduced_functional_numpy.py in get_global(self, m)
#      52                 m_global += v._ad_to_list(v)
#      53             else:
# ---> 54                 m_global += self.controls[i].control._ad_to_list(v)
#      55         return numpy.array(m_global, dtype="d")
#      56
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/fenics_adjoint/types/constant.py in _ad_to_list(m)
#      75     @staticmethod
#      76     def _ad_to_list(m):
# ---> 77         a = numpy.zeros(m.value_size())
#      78         p = numpy.zeros(m.value_size())
#      79         m.eval(a, p)
#
# AttributeError: 'NoneType' object has no attribute 'value_size'

# %%
import dolfin_adjoint as d_ad
from data_processing import scalar_img_to_mesh
def plot_mesh(ax, f, mesh, lw=False, scale=1, vmin=0, vmax=1, **kwargs):
    x, y = mesh.coordinates()[:, 0], mesh.coordinates()[:, 1]
    tri = mesh.cells()
    if lw:
        kwargs['edgecolors'] = 'black'
        kwargs['linewidth'] = 0.05
    if not isinstance(f, np.ndarray):
        ax.tripcolor(x, y, f.compute_vertex_values() * scale, triangles=tri, vmin=vmin, vmax=vmax, **kwargs)
    else:
        ax.tripcolor(x, y, f * scale, triangles=tri, vmin=vmin, vmax=vmax, **kwargs)
    ax.set(xticks=[], yticks=[])

from data_processing import CensusDataset
county = 'cook_IL'
dataset = CensusDataset(county)

fig, ax = plt.subplots(3, 2, dpi=150, sharey=True, sharex=True)

sample = dataset.get_time(1980)
ax[0,0].pcolormesh(sample['x'], sample['y'], sample['wb0'][0], cmap='Blues', vmax=1, vmin=0)
ax[0,1].pcolormesh(sample['x'], sample['y'], sample['wb0'][1], cmap='Reds', vmax=1, vmin=0)

sample = dataset[30]

#Generate fields on mesh
V = sample['FctSpace']
N = V.dim()
Dww = d_ad.Function(V)
Dwb = d_ad.Function(V)
Dbw = d_ad.Function(V)
Dbb = d_ad.Function(V)
w0 = d_ad.Function(V)
b0 = d_ad.Function(V)

Dww.vector()[:] = sample['control_arr'][:N]
Dwb.vector()[:] = sample['control_arr'][N:2*N]
Dbw.vector()[:] = sample['control_arr'][2*N:3*N]
Dbb.vector()[:] = sample['control_arr'][3*N:4*N]

GammaW = d_ad.Constant(sample['control_arr'][4*N], name='gammaW')
GammaB = d_ad.Constant(sample['control_arr'][4*N+1], name='gammaB')
dt = d_ad.Constant(sample['dt'], name='dt')
#w0 = scalar_img_to_mesh(sample['wb0'][0], sample['x'], sample['y'], sample['FctSpace'])
#b0 = scalar_img_to_mesh(sample['wb0'][1], sample['x'], sample['y'], sample['FctSpace'])
w0.vector()[:] = sample['control_arr'][4*N+3:5*N+3]
b0.vector()[:] = sample['control_arr'][5*N+3:6*N+3]

wb, _, _ = sample['pde_forward'](Dww, Dwb, Dbw, Dbb, GammaW, GammaB, 10, w0, b0, dataset.mesh)
w1, b1 = wb.split(True)

plot_mesh(ax[1,0], w0, dataset.mesh, cmap='Blues')
plot_mesh(ax[1,1], b0, dataset.mesh, cmap='Reds')

plot_mesh(ax[2,0], w1, dataset.mesh, cmap='Blues')
plot_mesh(ax[2,1], b1, dataset.mesh, cmap='Reds')

ax[0,0].set_title('White occupation', fontsize=8)
ax[0,1].set_title('Black occupation', fontsize=8)
ax[0,0].set_ylabel('1980')
ax[1,0].set_ylabel('2020')
ax[2,0].set_ylabel('2030 (predicted)')
for a in ax.flatten():
    a.set_aspect('equal')
    a.set(xticks=[], yticks=[])
plt.tight_layout()

# %%
from pbnn import PBNN
from time import time
import dolfin_adjoint as d_ad
from tqdm.auto import tqdm

model = PBNN().to(device)
opt = torch.optim.Adam(model.parameters(), lr=3e-4)
sch = torch.optim.lr_scheduler.ExponentialLR(opt, gamma=0.98)
loss_history = []

d_ad.set_working_tape(d_ad.Tape())

gammas_init = torch.ones(2, dtype=torch.float, device=device)

n_epochs = 100
step = 0
batch_size = 8

with tqdm(total=n_epochs) as pbar, \
     tqdm(total=n_epochs*len(dataset)) as ebar:
    for epoch in range(n_epochs):
        for i in range(len(dataset)):
            batch = dataset[i]
            batch['wb0'] = batch['wb0'].to(device)
            batch['Dij'] = batch['Dij'].to(device)
            batch['gammas'] = gammas_init
            batch['mask'] = torch.BoolTensor(batch['mask']).to(device)

            loss, Dij, gammas = model.pretrain(batch)
            loss_history.append(loss.item())
            step += 1
            ebar.update()

            if step % batch_size == 0:
                pbar.set_postfix(
                    loss=np.mean(loss_history[-batch_size:]),
                    gammas=gammas)

                opt.step()
                d_ad.set_working_tape(d_ad.Tape())
                opt.zero_grad()
                    
        
        torch.save(
            {
                'state_dict': model.state_dict(),
                'loss_history': loss_history,
            },
            'pbnn_pretrain.ckpt')

        sch.step()
        pbar.update()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/4000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-cd681ac2fe6d> in <module>
#      21     for epoch in range(n_epochs):
#      22         for i in range(len(dataset)):
# ---> 23             batch = dataset[i]
#      24             batch['wb0'] = batch['wb0'].to(device)
#      25             batch['Dij'] = batch['Dij'].to(device)
#
# ~/sociohydro/physical_bottleneck/data_processing.py in __getitem__(self, idx)
#     198             dt *= np.random.random()
#     199
# --> 200         sample = self.get_time(t0, dt)
#     201         sample['wb0'] = torch.FloatTensor(sample['wb0'])
#     202
#
# ~/sociohydro/physical_bottleneck/data_processing.py in get_time(self, t, dt)
#     185             'wb1': self.wb(t+dt),
#     186         }
# --> 187         pde = self.get_dolfin(sample)
#     188         return {**sample, **pde}
#     189
#
# ~/sociohydro/physical_bottleneck/data_processing.py in get_dolfin(self, sample)
#     140         w, b = wb.split(True)
#     141         J = d_ad.assemble(ufl.dot(w - w1, w - w1) * ufl.dx + \
# --> 142                           ufl.dot(b - b1, b - b1) * ufl.dx)
#     143
#     144         #Build controls to allow for updating values
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/fenics_adjoint/assembly.py in assemble(*args, **kwargs)
#      22
#      23         if annotate:
# ---> 24             block = AssembleBlock(form)
#      25
#      26             tape = get_working_tape()
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/fenics_adjoint/assembly.py in __init__(self, form)
#      72         self.add_dependency(mesh)
#      73         for c in self.form.coefficients():
# ---> 74             self.add_dependency(c, no_duplicates=True)
#      75
#      76     def __str__(self):
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/block.py in add_dependency(self, dep, no_duplicates)
#      49         """
#      50         if not no_duplicates or dep.block_variable not in self._dependencies:
# ---> 51             dep._ad_will_add_as_dependency()
#      52             self._dependencies.append(dep.block_variable)
#      53
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/overloaded_type.py in _ad_will_add_as_dependency(self)
#     364             with FloatingType.stop_floating(self):
#     365                 self._ad_annotate_block()
# --> 366         self.block_variable.save_output(overwrite=True)
#     367
#     368     def _ad_will_add_as_output(self):
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/tape.py in wrapper(*args, **kwargs)
#      44     def wrapper(*args, **kwargs):
#      45         with stop_annotating():
# ---> 46             return function(*args, **kwargs)
#      47
#      48     return wrapper
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/block_variable.py in save_output(self, overwrite)
#      49     def save_output(self, overwrite=True):
#      50         if overwrite or self.checkpoint is None:
# ---> 51             self._checkpoint = self.output._ad_create_checkpoint()
#      52
#      53     @property
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/fenics_adjoint/types/function.py in _ad_create_checkpoint(self)
#     158         dep = self.block.get_dependencies()[0]
#     159         return backend.Function.sub(dep.saved_output, self.block.idx,
# --> 160                                     deepcopy=True)
#     161
#     162     def _ad_restore_at_checkpoint(self, checkpoint):
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/dolfin/function/function.py in sub(self, i, deepcopy)
#     517         if deepcopy:
#     518             return Function(self.function_space().sub(i),
# --> 519                             self.cpp_object().sub(i),
#     520                             name='%s-%d' % (str(self), i))
#     521         else:
#
# KeyboardInterrupt:

# %%
plt.plot(loss_history)

# %%
info = torch.load('pbnn_pretrain.ckpt')
model = PBNN().to(device)
model.load_state_dict(info['state_dict'])

opt = torch.optim.Adam(model.parameters(), lr=3e-4)
sch = torch.optim.lr_scheduler.ExponentialLR(opt, gamma=0.98)
train_loss = []
val_loss = []


gammas_init = torch.ones(2, dtype=torch.float, device=device)

n_epochs = 100
step = 0
batch_size = 8

with tqdm(total=n_epochs) as pbar:
    for epoch in range(n_epochs):
        dataset.training()
        d_ad.set_working_tape(d_ad.Tape())

        with tqdm(total=len(dataset), leave=False) as ebar:
            for i in range(len(dataset)):
                batch = dataset[i]
                batch['wb0'] = batch['wb0'].to(device)
                
                Dij, Dij_mesh, constants, J, dJdD = model.training_step(batch)
                train_loss.append(J)
                step += 1
                ebar.update()

                if step % batch_size == 0:
                    pbar.set_postfix(
                        loss=np.mean(train_loss[-batch_size:]),
                        gammas=gammas)

                    opt.step()
                    d_ad.set_working_tape(d_ad.Tape())
                    opt.zero_grad()
                    
        dataset.validate()
        val_loss.append(0)
        
        with tqdm(total=len(dataset), leave=False) as ebar:
            with torch.no_grad():
                for i in range(len(dataset)):
                    d_ad.set_working_tape(d_ad.Tape())

                    batch = dataset[i]
                    batch['wb0'] = batch['wb0'].to(device)

                    Dij, Dij_mesh, constants, J = model.validation_step(batch)
                    val_loss[epoch] += J
                    ebar.update()

        
        torch.save(
            {
                'state_dict': model.state_dict(),
                'val_loss': val_loss,
                'train_loss': train_loss,
            },
            f'{model.__class__.__name__}.ckpt')

        sch.step()
        pbar.update()
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
#   0%|          | 0/40 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-4f7ac75cad36> in <module>
#      25                 batch['wb0'] = batch['wb0'].to(device)
#      26
# ---> 27                 Dij, Dij_mesh, constants, J, dJdD = model.training_step(batch)
#      28                 train_loss.append(J)
#      29                 step += 1
#
# ~/sociohydro/physical_bottleneck/pbnn.py in training_step(self, sample)
#      84
#      85         J = sample['Jhat'](control_arr)
# ---> 86         dJdD = sample['Jhat'].derivative(control_arr, forget=True, project=False)
#      87         grad = torch.tensor(dJdD, device=Dij.device) / sample['dt']
#      88
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/tape.py in wrapper(*args, **kwargs)
#      44     def wrapper(*args, **kwargs):
#      45         with stop_annotating():
# ---> 46             return function(*args, **kwargs)
#      47
#      48     return wrapper
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/reduced_functional_numpy.py in derivative(self, m_array, forget, project)
#      68         # if m_array is not None:
#      69         #    self.__call__(m_array)
# ---> 70         dJdm = self.rf.derivative()
#      71         dJdm = Enlist(dJdm)
#      72
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/reduced_functional.py in derivative(self, options)
#      63                                        options=options,
#      64                                        tape=self.tape,
# ---> 65                                        adj_value=self.scale)
#      66
#      67         # Call callback
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/drivers.py in compute_gradient(J, m, options, tape, adj_value)
#      27     with stop_annotating():
#      28         with tape.marked_nodes(m):
# ---> 29             tape.evaluate_adj(markings=True)
#      30
#      31     grads = [i.get_derivative(options=options) for i in m]
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/tape.py in evaluate_adj(self, last_block, markings)
#     138     def evaluate_adj(self, last_block=0, markings=False):
#     139         for i in range(len(self._blocks) - 1, last_block - 1, -1):
# --> 140             self._blocks[i].evaluate_adj(markings=markings)
#     141
#     142     def evaluate_tlm(self):
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/tape.py in wrapper(*args, **kwargs)
#      44     def wrapper(*args, **kwargs):
#      45         with stop_annotating():
# ---> 46             return function(*args, **kwargs)
#      47
#      48     return wrapper
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/pyadjoint/block.py in evaluate_adj(self, markings)
#     131                                                      dep,
#     132                                                      idx,
# --> 133                                                      prepared)
#     134             if adj_output is not None:
#     135                 dep.add_adj_output(adj_output)
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/fenics_adjoint/solving.py in evaluate_adj_component(self, inputs, adj_inputs, block_variable, idx, prepared)
#     260
#     261         dFdm = -backend.derivative(F_form, c_rep, trial_function)
# --> 262         dFdm = backend.adjoint(dFdm)
#     263         dFdm = dFdm * adj_sol
#     264         dFdm = compat.assemble_adjoint_value(dFdm, **self.assemble_kwargs)
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/dolfin/fem/formmanipulations.py in adjoint(form, reordered_arguments)
#      49
#      50     # Call ufl.adjoint with swapped arguments as new arguments
# ---> 51     return ufl.adjoint(form, reordered_arguments=(v_1, v_0))
#      52
#      53
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/formoperators.py in adjoint(form, reordered_arguments)
#     140     """
#     141     form = as_form(form)
# --> 142     form = expand_derivatives(form)
#     143     return compute_form_adjoint(form, reordered_arguments)
#     144
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/algorithms/ad.py in expand_derivatives(form, **kwargs)
#      43
#      44     # Apply differentiation
# ---> 45     form = apply_derivatives(form)
#      46
#      47     return form
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/algorithms/apply_derivatives.py in apply_derivatives(expression)
#    1093 def apply_derivatives(expression):
#    1094     rules = DerivativeRuleDispatcher()
# -> 1095     return map_integrand_dags(rules, expression)
#    1096
#    1097
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/algorithms/map_integrands.py in map_integrand_dags(function, form, only_integral_type, compress)
#      56 def map_integrand_dags(function, form, only_integral_type=None, compress=True):
#      57     return map_integrands(lambda expr: map_expr_dag(function, expr, compress),
# ---> 58                           form, only_integral_type)
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/algorithms/map_integrands.py in map_integrands(function, form, only_integral_type)
#      37     if isinstance(form, Form):
#      38         mapped_integrals = [map_integrands(function, itg, only_integral_type)
# ---> 39                             for itg in form.integrals()]
#      40         nonzero_integrals = [itg for itg in mapped_integrals
#      41                              if not isinstance(itg.integrand(), Zero)]
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/algorithms/map_integrands.py in <listcomp>(.0)
#      37     if isinstance(form, Form):
#      38         mapped_integrals = [map_integrands(function, itg, only_integral_type)
# ---> 39                             for itg in form.integrals()]
#      40         nonzero_integrals = [itg for itg in mapped_integrals
#      41                              if not isinstance(itg.integrand(), Zero)]
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/algorithms/map_integrands.py in map_integrands(function, form, only_integral_type)
#      44         itg = form
#      45         if (only_integral_type is None) or (itg.integral_type() in only_integral_type):
# ---> 46             return itg.reconstruct(function(itg.integrand()))
#      47         else:
#      48             return itg
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/algorithms/map_integrands.py in <lambda>(expr)
#      55
#      56 def map_integrand_dags(function, form, only_integral_type=None, compress=True):
# ---> 57     return map_integrands(lambda expr: map_expr_dag(function, expr, compress),
#      58                           form, only_integral_type)
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/corealg/map_dag.py in map_expr_dag(function, expression, compress)
#      35     Return the result of the final function call.
#      36     """
# ---> 37     result, = map_expr_dags(function, [expression], compress=compress)
#      38     return result
#      39
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/corealg/map_dag.py in map_expr_dags(function, expressions, compress)
#      84                 r = handlers[v._ufl_typecode_](v)
#      85             else:
# ---> 86                 r = handlers[v._ufl_typecode_](v, *[vcache[u] for u in v.ufl_operands])
#      87
#      88             # Optionally check if r is in rcache, a memory optimization
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/algorithms/apply_derivatives.py in coefficient_derivative(self, o, f, dummy_w, dummy_v, dummy_cd)
#    1055         dummy, w, v, cd = o.ufl_operands
#    1056         rules = GateauxDerivativeRuleset(w, v, cd)
# -> 1057         return map_expr_dag(rules, f)
#    1058
#    1059     def coordinate_derivative(self, o, f, dummy_w, dummy_v, dummy_cd):
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/corealg/map_dag.py in map_expr_dag(function, expression, compress)
#      35     Return the result of the final function call.
#      36     """
# ---> 37     result, = map_expr_dags(function, [expression], compress=compress)
#      38     return result
#      39
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/corealg/map_dag.py in map_expr_dags(function, expressions, compress)
#      75     for expression in expressions:
#      76         # Iterate over all subexpression nodes, child before parent
# ---> 77         for v in traversal(expression):
#      78             # Skip transformations on cache hit
#      79             if v in vcache:
#
# /project/vitelli/ml_venv/lib/python3.7/site-packages/ufl/corealg/traversal.py in cutoff_unique_post_traversal(expr, cutofftypes, visited)
#     147     while stacksize > 0:
#     148         expr, ops = stack[stacksize - 1]
# --> 149         for i, o in enumerate(ops):
#     150             if o is not None and o not in visited:
#     151                 stack[stacksize] = (o, () if cutofftypes[o._ufl_typecode_] else list(o.ufl_operands))
#
# KeyboardInterrupt:

# %%
plt.plot(train_loss)
plt.plot(val_loss)

# %% [markdown]
# # Older version

# %%
from pbnn import PBNN
from time import time
import dolfin_adjoint as d_ad
from tqdm.auto import tqdm

model = PBNN().to(device)
opt = torch.optim.Adam(model.parameters(), lr=3e-4)
sch = torch.optim.lr_scheduler.ExponentialLR(opt, gamma=0.995)
batch_size = 8
loss_history = []

d_ad.set_working_tape(d_ad.Tape())

loader = iter(dataset)

gammas_init = torch.ones(2, dtype=torch.float, device=device)

n_steps = 50000

with tqdm(total=n_steps) as pbar:
    for step in range(n_steps):
        t = time()

        batch = next(loader)
        batch['wb0'] = batch['wb0'].to(device)
        batch['Dij'] = batch['Dij_init'].to(device)
        batch['gammas'] = gammas_init
        batch['mask'] = torch.BoolTensor(batch['mask']).to(device)
        
        loss, Dij, gammas = model.pretrain(batch)
        loss_history.append(loss.item())

        if step > 0 and step % batch_size == 0:
            print(f'Time = {time() - t:.3g}\tLoss = {np.mean(loss_history[-batch_size:]):.5g}, Gammas={model.gammas.detach().cpu().numpy()}')

            opt.step()
            sch.step()
            d_ad.set_working_tape(d_ad.Tape())

            torch.save(
                {
                    'state_dict': model.state_dict(),
                    'loss_history': loss_history,
                },
                'pbnn_pretrain.ckpt')

        pbar.update()

# %%
plt.plot(loss_history)

# %%
info = torch.load('pbnn_pretrain.ckpt')
model = PBNN().to(device)
model.load_state_dict(info['state_dict'])

opt = torch.optim.Adam(model.parameters(), lr=3e-4)
sch = torch.optim.lr_scheduler.ExponentialLR(opt, gamma=0.995)
batch_size = 8
loss_history = []

d_ad.set_working_tape(d_ad.Tape())

loader = iter(dataset)

with tqdm(total=n_steps) as pbar:
    for step in range(n_steps):
        t = time()
        batch = next(loader)

        Dij, Dij_mesh, constants, J, dJdD = model.step(
            batch['wb0'].to(device),
            batch['Jhat'],
            batch['control_arr'],
            batch['FctSpace'],
            (batch['x'], batch['y']),
            batch['dt']
        )
        loss_history.append(J)

        if step > 0 and step % batch_size == 0:
            print(f'Time = {time() - t:.3g}\tLoss = {np.mean(loss_history[-batch_size:]):.5g}, Gammas={model.gammas.detach().cpu().numpy()}')

            opt.step()
            sch.step()
            d_ad.set_working_tape(d_ad.Tape())

            torch.save(
                {
                    'state_dict': model.state_dict(),
                    'loss_history': loss_history,
                },
                'pbnn.ckpt')

        pbar.update()

# %%
plt.plot(loss_history)
